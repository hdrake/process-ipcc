# %%
#import types
from git import Repo
import os
import numpy as np
import xarray as xr
import pandas as pd
import scipy
import Nio
import datetime
import sys

script_full_path = '/scripts/convert_grb_to_netcdf.py'

# %% [markdown]
# # Process TAR models

# %%
# Second Assessment Report (SAR) Model Output

dir_path = "../data/raw/SAR/"

def add_metadata(ds,run_name):
    metadata_path = '../data/metadata/sar_models.csv'
    data = pd.read_csv(metadata_path,sep=',')
    ds.attrs['run_description'] = np.str(
        data['run_description'][list(data['run_name']).index(run_name.replace('CI01','GS01'))]
    ).replace('nan','N/A')
    
    ds.attrs['model_description'] = np.str(
        data['model_description'][list(data['run_name']).index(run_name.replace('CI01','GS01'))]
    ).replace('nan','N/A')
    return ds

def date_to_datetime(dates,reference_date):
    date = np.array(
        [datestr.split(" ")[0].split("/")[2] + "-" +
         datestr.split(" ")[0].split("/")[0] + "-" +
         datestr.split(" ")[0].split("/")[1]
         for datestr in np.array(dates.values).astype("str")]
    ).astype("datetime64")
    return (date-reference_date)/np.array([1]).astype("<m8[D]")

# Main loop
nexp = 0
for institution in os.listdir(dir_path):
    if ("." in institution): continue
    for file_name in os.listdir(dir_path+institution+"/"):
        nexp+=1
print("Total # of experiments: "+str(nexp))

# Variable metadata copied from http://cfconventions.org/Data/cf-standard-names/27/build/cf-standard-name-table.html
standard_dict = {}
standard_dict['long_name'] = {
    'tas': 'Near-Surface Air Temperature',
    'psl': 'Sea Level Pressure',
    'pr': 'Precipitation',
    'rsds': 'Downwelling Shortwave Flux at Surface',
    'sn': 'Snow Amount',
    'tasmax': 'Maximum Near-Surface Air Temperature',
    'tasmin': 'Minimum Near-Surface Air Temperature',
    'sfcWind': 'Near-Surface Wind Speed'
}
standard_dict['description'] = {
    'tas': 'temperature at 2-meter height',
    'psl': 'not, in general, the same as surface pressure',
    'pr': 'at surface; includes both liquid and solid phases from all types of clouds',
    'rsds': """
    The surface called "surface" means the lower boundary of the atmosphere. 
    "shortwave" means shortwave radiation. Downwelling radiation is radiation from above.
    It does not mean "net downward". Surface downwelling shortwave is the sum of direct
    and diffuse solar radiation incident on the surface, and is sometimes called "global
    radiation". When thought of as being incident on a surface, a radiative flux is
    sometimes called "irradiance". In addition, it is identical with the quantity measured
    by a cosine-collector light-meter and sometimes called "vector irradiance". In
    accordance with common usage in geophysical disciplines, "flux" implies
    per unit area, called "flux density" in physics.
    """,
    'sn': '"Amount" means mass per unit area.',
    'tasmax': 'Monthly-mean daily-maximum temperature at 2-meter height',
    'tasmin': 'Monthly-mean daily-minimum temperature at 2-meter height',
    'sfcWind': """
    'Speed is the magnitude of velocity. Wind is defined as a two-dimensional (horizontal)
    air velocity vector, with no vertical component. (Vertical motion in the atmosphere has
    the standard name upward_air_velocity.) The wind speed is the magnitude of the wind
    velocity.'
    """
}
standard_dict['standard_name'] = {
    'tas': 'air_temperature',
    'psl': 'air_pressure_at_sea_level',
    'pr': 'precipitation_flux',
    'rsds': 'surface_downwelling_shortwave_flux',
    'sn': 'snow_amount',
    'tasmax': 'air_temperature',
    'tasmin': 'air_temperature',
    'sfcWind': 'wind_speed'
}
standard_dict['units'] = {
    'tas': 'K',
    'psl': 'Pa',
    'pr': 'kg m^-2 s^-1',
    'rsds': 'W m^-2',
    'sn': 'kg m^-2',
    'tasmax': 'K',
    'tasmin': 'K',
    'sfcWind': 'm s^-1'
}

for institution in os.listdir(dir_path):
    if ("." == institution[0]): continue
    stop = 0
    for var_name in os.listdir(dir_path+institution+"/"):
        if ("." == var_name[0]): continue
        for file_name in os.listdir(dir_path+institution+"/"+var_name+"/"):
            if ("." == file_name[0]): continue
                
            run_name = str.split(file_name,"_")[0]
            
            print("\n"+institution+"/"+var_name+"/"+file_name, end="")

            # Load data into xarray dataset using PyNio engine
            ds = xr.open_dataset(dir_path+institution+"/"+var_name+"/"+file_name,engine="pynio",decode_times=False)
            
            # Make coordinates CF-compliant and convert dates to decimal years
            reference_date = np.datetime64("1990","D")
            date = date_to_datetime(ds['initial_time0'],reference_date)
            var_change_dict = {}
            var_change_dict[list(ds.dims)[0]] = 'latitude'
            var_change_dict[list(ds.dims)[1]] = 'longitude'
            var_change_dict[list(ds.dims)[2]] = 'time'
            ds = ds.rename(var_change_dict)
            ds.coords['latitude'].attrs['axis']='Y'
            ds.coords['latitude'].attrs['standard_name'] = 'latitude'
            ds.coords['longitude'].attrs['axis']='X'
            ds.coords['longitude'].attrs['standard_name'] = 'longitude'
            ds.coords['time'].attrs['long_name'] = 'time'
            ds.coords['time'].attrs['axis'] = 'T'
            ds.coords['time'].attrs['calendar'] = 'standard'
            ds.coords['time'].values = date
            ds.coords['time'].attrs['units'] = 'days since 1990-01-01 0:0:0'
            ds = ds.drop(['initial_time0_encoded','initial_time0'])

            # Give temperature variable to standard names and description
            var_names = ds.variables.keys()
            for nam in var_names:
                if not(("latitude" in nam) or ("longitude" in nam) or ("time" in nam)):
                    ds = ds.rename({nam:var_name})

            # Convert precipitation data from kg/m^2/day (is this really the units?) to kg/m^2/s
            if var_name == "pr":
                ds[var_name] /= (24.*60.*60.)
                        
            for attrs_name in list(standard_dict.keys()):
                ds[var_name].attrs[attrs_name] = standard_dict[attrs_name][var_name]
                
            ds[var_name] = ds[var_name].where(ds[var_name]!=-999., np.nan)
            
            # Fix MPIfM
            if institution == "MPIfM":
                ds['latitude'].values = ds['latitude'].values[::-1]
            
            # Declare CF-convention compliance
            ds.attrs['Conventions'] = 'CF-1.7'

            # Metadata 
            ds.attrs['title'] = 'Projections from a Second Assessment Report model'
            ds.attrs['institution'] = institution
            ds.attrs['modelling_center'] = ds[var_name].attrs['center']
            if 'model' in ds.attrs:
                ds.attrs['source'] = ds[var_name].attrs['model']
            else: 
                ds.attrs['source'] = 'N/A'

            # Generate data provenance entry:
            # time stamp, command line arguments, environment, and hash for git commit
            time_stamp = datetime.datetime.now().strftime("%a %b %d %H:%M:%S %Y")
            args = " ".join(sys.argv)
            exe = sys.executable
            git_hash = Repo(os.getcwd()+'/..').head.commit.hexsha[0:7]
            history_entry = ("{time_stamp}: {exe} {args} {script_full_path} (Git hash: {git_hash})"
                     .format(time_stamp=time_stamp,
                             exe=exe,
                             args=args,
                             script_full_path=script_full_path,
                             git_hash = git_hash))
            ds.attrs['history'] = history_entry

            # Write xarray dataset to netCDF4 file
            ncfile_name = "../data/interim/SAR/"+run_name+"_"+var_name+".nc"

            ds.to_netcdf(ncfile_name,mode='w')
            ds.close()
# Out:
# Total # of experiments: 58
#
# CCSR-NIES/sfcWind/NI01GG01_WNDS_1-2520.grb
# CCSR-NIES/sfcWind/NI01GS01_WNDS_1-2520.grb
# CCSR-NIES/sfcWind/NI01CI01_WNDS_1-2520.grb
# CCSR-NIES/tas/NI01GS01_TA___1-2520.grb
# CCSR-NIES/tas/NI01GG01_TA___1-2520.grb
# CCSR-NIES/tas/NI01CI01_TA___1-2520.grb
# CCSR-NIES/tasmin/NI01GG01_TMIN_1-2520.grb
# CCSR-NIES/tasmin/NI01CI01_TMIN_1-2520.grb
# CCSR-NIES/tasmin/NI01GS01_TMIN_1-2520.grb
# CCSR-NIES/tasmax/NI01GS01_TMAX_1-2520.grb
# CCSR-NIES/tasmax/NI01CI01_TMAX_1-2520.grb
# CCSR-NIES/tasmax/NI01GG01_TMAX_1-2520.grb
# CCSR-NIES/pr/NI01GS01_RAIN_1-2520.grb
# CCSR-NIES/pr/NI01GG01_RAIN_1-2520.grb
# CCSR-NIES/pr/NI01CI01_RAIN_1-2520.grb
# CCSR-NIES/rsds/NI01GG01_SSR__1-2520.grb
# CCSR-NIES/rsds/NI01CI01_SSR__1-2520.grb
# CCSR-NIES/rsds/NI01GS01_SSR__1-2520.grb
# CCSR-NIES/psl/NI01GS01_SLP__1-2520.grb
# CCSR-NIES/psl/NI01CI01_SLP__1-2520.grb
# CCSR-NIES/psl/NI01GG01_SLP__1-2520.grb
# CSIRO/tas/CS01GG01_TAS__1-2640.grb
# CSIRO/tas/CS01GS01_TAS__1-2640.grb
# CSIRO/tas/CS01CI01_TAS__1-2640.grb
# CSIRO/tasmin/CS01GS01_TMIN_1-2640.grb
# CSIRO/tasmin/CS01CI01_TMIN_1-2640.grb
# CSIRO/tasmin/CS01GG01_TMIN_1-2640.grb
# CSIRO/tasmax/CS01GG01_TMAX_1-2640.grb
# CSIRO/tasmax/CS01CI01_TMAX_1-2640.grb
# CSIRO/tasmax/CS01GS01_TMAX_1-2640.grb
# CSIRO/pr/CS01GS01_PR___1-2640.grb
# CSIRO/pr/CS01GG01_PR___1-2640.grb
# CSIRO/pr/CS01CI01_PR___1-2640.grb
# CSIRO/rsds/CS01GS01_RSNS_1-2640.grb
# CSIRO/rsds/CS01CI01_RSNS_1-2640.grb
# CSIRO/rsds/CS01GG01_RSNS_1-2640.grb
# CSIRO/psl/CS01GS01_PSL__1-2640.grb
# CSIRO/psl/CS01CI01_PSL__1-2640.grb
# CSIRO/psl/CS01GG01_PSL__1-2640.grb
# GFDL/tas/GF01GS01_T9___1-3600.grb
# GFDL/tas/GF01GG01_T9___1-1200.grb
# GFDL/tas/GF01CI01_T9___1-12000.grb
# GFDL/pr/GF01GS01_PREC_1-3600.grb
# GFDL/pr/GF01CI01_PREC_1-12000.grb
# GFDL/pr/GF01GG01_PREC_1-1200.grb
# GFDL/rsds/GF01GS01_SWBO_1-3600.grb
# GFDL/rsds/GF01CI01_SWBO_1-12000.grb
# GFDL/rsds/GF01GG01_SWBO_1-1200.grb
# GFDL/psl/GF01GG01_PSRF_1-1200.grb
# GFDL/psl/GF01GS01_PSRF_1-3600.grb
# GFDL/psl/GF01CI01_PSRF_1-12000.grb
# MPIfM/sfcWind/MP01GS01_UB10_1-2280.grb
# MPIfM/sfcWind/MP01CI01_UB10_1-2880.grb
# MPIfM/sfcWind/MP01GS02_UB10_1-2292.grb
# MPIfM/sfcWind/MP01GG01_UB10_1-2880.grb
# MPIfM/tas/MP01CI01_T2M__1-2880.grb
# MPIfM/tas/MP01GS01_T2M__1-2280.grb
# MPIfM/tas/MP01GS02_T2M__1-2292.grb
# MPIfM/tas/MP01GG01_T2M__1-2880.grb
# MPIfM/tasmin/MP01GS01_T2MI_1-2280.grb
# MPIfM/tasmin/MP01CI01_T2MI_1-2880.grb
# MPIfM/tasmin/MP01GS02_T2MI_1-2292.grb
# MPIfM/tasmin/MP01GG01_T2MI_1-2880.grb
# MPIfM/tasmax/MP01GG01_T2MA_1-2880.grb
# MPIfM/tasmax/MP01CI01_T2MA_1-2880.grb
# MPIfM/tasmax/MP01GS01_T2MA_1-2280.grb
# MPIfM/tasmax/MP01GS02_T2MA_1-2292.grb
# MPIfM/pr/MP01GG01_APRT_1-2880.grb
# MPIfM/pr/MP01CI01_APRT_1-2880.grb
# MPIfM/pr/MP01GS01_APRT_1-2280.grb
# MPIfM/pr/MP01GS02_APRT_1-2292.grb
# MPIfM/rsds/MP01GS01_SRDS_1-2280.grb
# MPIfM/rsds/MP01CI01_SRDS_1-2880.grb
# MPIfM/rsds/MP01GS02_SRDS_1-2292.grb
# MPIfM/rsds/MP01GG01_SRDS_1-2880.grb
# MPIfM/psl/MP01CI01_MSLP_1-2880.grb
# MPIfM/psl/MP01GS01_MSLP_1-2280.grb
# MPIfM/psl/MP01GS02_MSLP_1-2292.grb
# MPIfM/psl/MP01GG01_MSLP_1-2880.grb
# CCCma/sfcWind/CC01GG01_SWMX_1-2400.grb
# CCCma/sfcWind/CC01GS03_SWMX_1-2400.grb
# CCCma/sfcWind/CC01GS02_SWMX_1-2400.grb
# CCCma/sfcWind/CC01GS01_SWMX_1-2400.grb
# CCCma/sfcWind/CC01CI01_SWMX_1-2400.grb
# CCCma/tas/CC01CI01_ST___1-2400.grb
# CCCma/tas/CC01GG01_ST___1-2400.grb
# CCCma/tas/CC01GS01_ST___1-2400.grb
# CCCma/tas/CC01GS02_ST___1-2400.grb
# CCCma/tas/CC01GS03_ST___1-2400.grb
# CCCma/tasmin/CC01GS01_STMN_1-2400.grb
# CCCma/tasmin/CC01GS03_STMN_1-2400.grb
# CCCma/tasmin/CC01GG01_STMN_1-2400.grb
# CCCma/tasmin/CC01GS02_STMN_1-2400.grb
# CCCma/tasmin/CC01CI01_STMN_1-2400.grb
# CCCma/tasmax/CC01CI01_STMX_1-2400.grb
# CCCma/tasmax/CC01GG01_STMX_1-2400.grb
# CCCma/tasmax/CC01GS01_STMX_1-2400.grb
# CCCma/tasmax/CC01GS02_STMX_1-2400.grb
# CCCma/tasmax/CC01GS03_STMX_1-2400.grb
# CCCma/pr/CC01GS03_PCP__1-2400.grb
# CCCma/pr/CC01GG01_PCP__1-2400.grb
# CCCma/pr/CC01GS01_PCP__1-2400.grb
# CCCma/pr/CC01GS02_PCP__1-2400.grb
# CCCma/pr/CC01CI01_PCP__1-2400.grb
# CCCma/rsds/CC01CI01_FSS__1-2400.grb
# CCCma/rsds/CC01GG01_FSS__1-2400.grb
# CCCma/rsds/CC01GS03_FSS__1-2400.grb
# CCCma/rsds/CC01GS01_FSS__1-2400.grb
# CCCma/rsds/CC01GS02_FSS__1-2400.grb
# CCCma/psl/CC01CI01_PMSL_1-2400.grb
# CCCma/psl/CC01GS01_PMSL_1-2400.grb
# CCCma/psl/CC01GG01_PMSL_1-2400.grb
# CCCma/psl/CC01GS03_PMSL_1-2400.grb
# CCCma/psl/CC01GS02_PMSL_1-2400.grb
# DKRZ/sfcWind/DK01GG01_UB10_1-2460.grb
# DKRZ/sfcWind/DK01GS01_UB10_1-2040.grb
# DKRZ/sfcWind/DK01CI01_UB10_1-2880.grb
# DKRZ/tas/DK01GG01_T2M__1-2460.grb
# DKRZ/tas/DK01CI01_T2M__1-2880.grb
# DKRZ/tas/DK01GS02_T2M__1-2040.grb
# DKRZ/tasmin/DK01GS01_T2MI_1-2040.grb
# DKRZ/tasmin/DK01CI01_T2MI_1-2880.grb
# DKRZ/tasmin/DK01GG01_T2MI_1-2460.grb
# DKRZ/tasmax/DK01GG01_T2MA_1-2460.grb
# DKRZ/tasmax/DK01GS01_T2MA_1-2040.grb
# DKRZ/tasmax/DK01CI01_T2MA_1-2880.grb
# DKRZ/pr/DK01GG01_APRT_1-2460.grb
# DKRZ/pr/DK01GS02_APRT_1-2040.grb
# DKRZ/pr/DK01CI01_APRT_1-2880.grb
# DKRZ/rsds/DK01GG01_SRDS_1-2460.grb
# DKRZ/rsds/DK01GS01_SRDS_1-2040.grb
# DKRZ/rsds/DK01CI01_SRDS_1-2880.grb
# DKRZ/psl/DK01CI01_MSLP_1-2880.grb
# DKRZ/psl/DK01GG01_MSLP_1-2460.grb
# NCAR/sfcWind/NC01GS01_WIND_1-1632.grb
# NCAR/sfcWind/NC01GG01_WIND_1-1632.grb
# NCAR/sfcWind/NC01CI01_WIND_1-1632.grb
# NCAR/tas/NC01CI01_TEMP_1-1632.grb
# NCAR/tas/NC01GS01_TEMP_1-1632.grb
# NCAR/tas/NC01GG01_TEMP_1-1632.grb
# NCAR/pr/NC01GG01_PREC_1-1632.grb
# NCAR/pr/NC01GS01_PREC_1-1632.grb
# NCAR/pr/NC01CI01_PREC_1-1632.grb
# NCAR/rsds/NC01CI01_FRSA_1-1632.grb
# NCAR/rsds/NC01GS01_FRSA_1-1632.grb
# NCAR/rsds/NC01GG01_FRSA_1-1632.grb
# NCAR/psl/NC01CI01_PSL__1-1632.grb
# NCAR/psl/NC01GG01_PSL__1-1632.grb
# NCAR/psl/NC01GS01_PSL__1-1632.grb
# HCCPR/sfcWind/HC01GG03_WIND_1-2880.grb
# HCCPR/sfcWind/HC01GG01_WIND_1-2880.grb
# HCCPR/sfcWind/HC02GG01_WIND_1-2880.grb
# HCCPR/sfcWind/HC01CI01_WIND_1-2880.grb
# HCCPR/sfcWind/HC01GS02_WIND_1-2880.grb
# HCCPR/sfcWind/HC02GS01_WIND_1-2880.grb
# HCCPR/sfcWind/HC01GS01_WIND_1-2880.grb
# HCCPR/sfcWind/HC02CI01_WIND_1-2880.grb
# HCCPR/sfcWind/HC01GG04_WIND_1-2880.grb
# HCCPR/sfcWind/HC01GS03_WIND_1-2880.grb
# HCCPR/sfcWind/HC01GS04_WIND_1-2880.grb
# HCCPR/tas/HC02GG01_TEMK_1-2880.grb
# HCCPR/tas/HC02CI01_TEMK_1-2880.grb
# HCCPR/tas/HC01GG02_TEMK_1-2880.grb
# HCCPR/tas/HC02GS01_TEMK_1-2880.grb
# HCCPR/tas/HC01GG01_TEMK_1-2880.grb
# HCCPR/tas/HC01GG03_TEMK_1-2880.grb
# HCCPR/tas/HC01GS04_TEMK_1-2880.grb
# HCCPR/tas/HC01GG04_TEMK_1-2880.grb
# HCCPR/tas/HC01CI01_TEMK_1-2880.grb
# HCCPR/tas/HC01GS01_TEMK_1-2880.grb
# HCCPR/tas/HC01GS03_TEMK_1-2880.grb
# HCCPR/tas/HC01GS02_TEMK_1-2880.grb
# HCCPR/tasmin/HC01GG04_TMIK_1-2880.grb
# HCCPR/tasmin/HC01GS02_TMIK_1-2880.grb
# HCCPR/tasmin/HC01GS03_TMIK_1-2880.grb
# HCCPR/tasmin/HC01GS01_TMIK_1-2880.grb
# HCCPR/tasmin/HC01GG03_TMIK_1-2880.grb
# HCCPR/tasmin/HC01GS04_TMIK_1-2880.grb
# HCCPR/tasmin/HC01CI01_TMIK_1-2880.grb
# HCCPR/tasmin/HC01GG01_TMIK_1-2880.grb
# HCCPR/tasmax/HC01GG04_TMAK_1-2880.grb
# HCCPR/tasmax/HC01GS01_TMAK_1-2880.grb
# HCCPR/tasmax/HC01CI01_TMAK_1-2880.grb
# HCCPR/tasmax/HC01GS04_TMAK_1-2880.grb
# HCCPR/tasmax/HC01GS02_TMAK_1-2880.grb
# HCCPR/tasmax/HC01GG03_TMAK_1-2880.grb
# HCCPR/tasmax/HC01GG01_TMAK_1-2880.grb
# HCCPR/tasmax/HC01GS03_TMAK_1-2880.grb
# HCCPR/pr/HC01GS03_PREC_1-2880.grb
# HCCPR/pr/HC02GG01_PREC_1-2880.grb
# HCCPR/pr/HC01GG02_PREC_1-2880.grb
# HCCPR/pr/HC02CI01_PREC_1-2880.grb
# HCCPR/pr/HC02GS01_PREC_1-2880.grb
# HCCPR/pr/HC01GS04_PREC_1-2880.grb
# HCCPR/pr/HC01GS02_PREC_1-2880.grb
# HCCPR/pr/HC01GG03_PREC_1-2880.grb
# HCCPR/pr/HC01GG01_PREC_1-2880.grb
# HCCPR/pr/HC01CI01_PREC_1-2880.grb
# HCCPR/pr/HC01GS01_PREC_1-2880.grb
# HCCPR/pr/HC01GG04_PREC_1-2880.grb
# HCCPR/rsds/HC02CI01_DSWF_1-2880.grb
# HCCPR/rsds/HC02GG01_DSWF_1-2880.grb
# HCCPR/rsds/HC01GS01_DSWF_1-2880.grb
# HCCPR/rsds/HC01CI01_DSWF_1-2880.grb
# HCCPR/rsds/HC02GS01_DSWF_1-2880.grb
# HCCPR/rsds/HC01GG01_DSWF_1-2880.grb
# HCCPR/psl/HC01GG02_MSLP_1-2880.grb
# HCCPR/psl/HC01CI01_MSLP_1-2880.grb
# HCCPR/psl/HC02CI01_MSLP_1-2880.grb
# HCCPR/psl/HC01GS04_MSLP_1-2880.grb
# HCCPR/psl/HC01GS02_MSLP_1-2880.grb
# HCCPR/psl/HC01GG04_MSLP_1-2880.grb
# HCCPR/psl/HC02GG01_MSLP_1-2880.grb
# HCCPR/psl/HC01GS03_MSLP_1-2880.grb
# HCCPR/psl/HC01GG03_MSLP_1-2880.grb
# HCCPR/psl/HC02GS01_MSLP_1-2880.grb
# HCCPR/psl/HC01GG01_MSLP_1-2880.grb
# HCCPR/psl/HC01GS01_MSLP_1-2880.grb

# %% [markdown]
# # Process TAR models

# %%
# Third Assessment Report (SAR) Model Output
dir_path = "../data/raw/TAR/"

# Main loop
nexp = 0
for institution in os.listdir(dir_path):
    if ("." in institution): continue
    for file_name in os.listdir(dir_path+institution+"/"):
        nexp+=1
print("\nTotal # of experiments: "+str(nexp))

for institution in os.listdir(dir_path):
    if ("." == institution[0]): continue
    stop = 0
    for var_name in os.listdir(dir_path+institution+"/"):
        if ("." == var_name[0]): continue
        for file_name in os.listdir(dir_path+institution+"/"+var_name+"/"):
            if ("." == file_name[0]): continue
                
            run_name = str.split(file_name,"_")[0]+"_"+str.split(file_name,"_")[1]+"-"+str.split(file_name,"_")[2]
            
            print("\n"+institution+"/"+var_name+"/"+file_name, end="")

            # Load data into xarray dataset using PyNio engine
            ds = xr.open_dataset(dir_path+institution+"/"+var_name+"/"+file_name,engine="pynio",decode_times=False)

            # Make coordinates CF-compliant and convert dates to decimal years
            reference_date = np.datetime64("1990","D")
            date = date_to_datetime(ds['initial_time0'],reference_date)
            var_change_dict = {}
            var_change_dict[list(ds.dims)[0]] = 'latitude'
            var_change_dict[list(ds.dims)[1]] = 'longitude'
            var_change_dict[list(ds.dims)[2]] = 'time'
            ds = ds.rename(var_change_dict)
            ds.coords['latitude'].attrs['axis']='Y'
            ds.coords['latitude'].attrs['standard_name'] = 'latitude'
            ds.coords['longitude'].attrs['axis']='X'
            ds.coords['longitude'].attrs['standard_name'] = 'longitude'
            ds.coords['time'].attrs['long_name'] = 'time'
            ds.coords['time'].attrs['axis'] = 'T'
            ds.coords['time'].attrs['calendar'] = 'standard'
            ds.coords['time'].values = date
            ds.coords['time'].attrs['units'] = 'days since 1990-01-01 0:0:0'
            ds = ds.drop(['initial_time0_encoded','initial_time0'])

            # Give temperature variable to standard names and description
            var_names = ds.variables.keys()
            for nam in var_names:
                if not(("latitude" in nam) or ("longitude" in nam) or ("time" in nam)):
                    ds = ds.rename({nam:var_name})

            for attrs_name in list(standard_dict.keys()):
                ds[var_name].attrs[attrs_name] = standard_dict[attrs_name][var_name]
                
            # Convert precipitation data from kg/m^2/day (is this really the units?) to kg/m^2/s
            if var_name == "pr":
                ds[var_name] /= (24.*60.*60.)
                
            ds[var_name] = ds[var_name].where(ds[var_name]!=-999., np.nan)

            # Fix EH4OPYC
            if institution == "MPIfM":
                ds['latitude'].values = ds['latitude'].values[::-1]
            
            # Declare CF-convention compliance
            ds.attrs['Conventions'] = 'CF-1.7'

            # Metadata 
            ds.attrs['title'] = 'Projections from a Third Assessment Report model'
            ds.attrs['institution'] = institution
            ds.attrs['modelling_center'] = ds[var_name].attrs['center']
            if 'model' in ds.attrs:
                ds.attrs['source'] = ds[var_name].attrs['model']
            else: 
                ds.attrs['source'] = 'N/A'

            #ds = add_metadata(ds,run_name)

            # Generate data provenance entry:
            # time stamp, command line arguments, environment, and hash for git commit
            time_stamp = datetime.datetime.now().strftime("%a %b %d %H:%M:%S %Y")
            args = " ".join(sys.argv)
            exe = sys.executable
            git_hash = Repo(os.getcwd()+'/..').head.commit.hexsha[0:7]
            history_entry = ("{time_stamp}: {exe} {args} {script_full_path} (Git hash: {git_hash})"
                     .format(time_stamp=time_stamp,
                             exe=exe,
                             args=args,
                             script_full_path=script_full_path,
                             git_hash = git_hash))
            ds.attrs['history'] = history_entry

            # Write xarray dataset to netCDF4 file
            ncfile_name = "../data/interim/TAR/"+run_name+"_"+var_name+".nc"
            ds.to_netcdf(ncfile_name,mode='w')
            ds.close()
# Out:
# Total # of experiments: 56
#
# CCSR-NIES/sfcWind/CCSRNIES_SRES_B2_WIND10_1-2532.grb
# CCSR-NIES/sfcWind/CCSRNIES_SRES_A2_WIND10_1-2532.grb
# CCSR-NIES/tas/CCSRNIES_SRES_A2_TS_1-2532.grb
# CCSR-NIES/tas/CCSRNIES_SRES_B2_TS_1-2532.grb
# CCSR-NIES/tasmin/CCSRNIES_SRES_A2_TMIN_1-2532.grb
# CCSR-NIES/tasmin/CCSRNIES_SRES_B2_TMIN_1-2532.grb
# CCSR-NIES/tasmax/CCSRNIES_SRES_B2_TMAX_1-2532.grb
# CCSR-NIES/tasmax/CCSRNIES_SRES_A2_TMAX_1-2532.grb
# CCSR-NIES/pr/CCSRNIES_SRES_A2_PREC_1-2532.grb
# CCSR-NIES/pr/CCSRNIES_SRES_B2_PREC_1-2532.grb
# CCSR-NIES/rsds/CCSRNIES_SRES_A2_DSWF_1-2532.grb
# CCSR-NIES/rsds/CCSRNIES_SRES_A2_DSWF_1-2532(1).grb
# CCSR-NIES/rsds/CCSRNIES_SRES_B2_DSWF_1-2532.grb
# CCSR-NIES/psl/CCSRNIES_SRES_A2_MSLP_1-2532.grb
# CCSR-NIES/psl/CCSRNIES_SRES_B2_MSLP_1-2532.grb
# CSIRO/sfcWind/CSIRO_SRES_A2_WIND10_1-1680.grb
# CSIRO/sfcWind/CSIRO_SRES_B2_WIND10_1-1680.grb
# CSIRO/tas/CSIRO_SRES_B2_TS_1-1680.grb
# CSIRO/tas/CSIRO_SRES_A2_TS_1-1680.grb
# CSIRO/tasmin/CSIRO_SRES_B2_TMIN_1-1680.grb
# CSIRO/tasmin/CSIRO_SRES_A2_TMIN_1-1680.grb
# CSIRO/tasmax/CSIRO_SRES_A2_TMAX_1-1680.grb
# CSIRO/tasmax/CSIRO_SRES_B2_TMAX_1-1680.grb
# CSIRO/pr/CSIRO_SRES_A2_PREC_1-1680.grb
# CSIRO/pr/CSIRO_SRES_B2_PREC_1-1680.grb
# CSIRO/rsds/CSIRO_SRES_A2_DSWF_1-1680.grb
# CSIRO/rsds/CSIRO_SRES_B2_DSWF_1-1680.grb
# CSIRO/psl/CSIRO_SRES_B2_MSLP_1-1680.grb
# CSIRO/psl/CSIRO_SRES_A2_MSLP_1-1680.grb
# CSIRO/sn/CSIRO_SRES_A2_SN_1-1680.grb
# GFDL/tas/GFDL_SRES_B2_TS_1-1680.grb
# GFDL/tas/GFDL_SRES_A2_TS_1-1680.grb
# GFDL/pr/GFDL_SRES_B2_PREC_1-1680.grb
# GFDL/pr/GFDL_SRES_A2_PREC_1-1680.grb
# GFDL/rsds/GFDL_SRES_A2_DSWF_1-1680.grb
# GFDL/rsds/GFDL_SRES_B2_DSWF_1-1680.grb
# GFDL/psl/GFDL_SRES_A2_PRES_1-1680.grb
# GFDL/psl/GFDL_SRES_B2_PRES_1-1680.grb
# GFDL/sn/GFDL_SRES_A2_SN_1-1680.grb
# MPIfM/sfcWind/EH4OPYC_SRES_A2_WIND10_1-1332.grb
# MPIfM/sfcWind/EH4OPYC_SRES_B2_WIND10_1-1332.grb
# MPIfM/tas/EH4OPYC_SRES_A2_TS_1-1332.grb
# MPIfM/tas/EH4OPYC_SRES_B2_TS_1-1332.grb
# MPIfM/tasmin/EH4OPYC_SRES_A2_TMIN_1-1332.grb
# MPIfM/tasmax/EH4OPYC_SRES_A2_TMAX_1-1332.grb
# MPIfM/pr/EH4OPYC_SRES_A2_PREC_1-1332.grb
# MPIfM/pr/EH4OPYC_SRES_B2_PREC_1-1332.grb
# MPIfM/rsds/EH4OPYC_SRES_A2_DSWF_1-1332.grb
# MPIfM/rsds/EH4OPYC_SRES_B2_DSWF_1-1332.grb
# MPIfM/psl/EH4OPYC_SRES_A2_MSLP_1-1332.grb
# MPIfM/psl/EH4OPYC_SRES_B2_MSLP_1-1332.grb
# MPIfM/sn/EH4OPYC_SRES_A2_SN_1-1332.grb
# CCCma/sfcWind/CCCma_SRES_A2_WIND_1-2412.grb
# CCCma/sfcWind/CCCma_SRES_B2_WIND_1-2412.grb
# CCCma/tas/CCCma_SRES_B2_TS_1-2412.grb
# CCCma/tas/CCCma_SRES_A2_TS_1-2412.grb
# CCCma/tasmin/CCCma_SRES_A2_TMIN_1-2412.grb
# CCCma/tasmin/CCCma_SRES_B2_TMIN_1-2412.grb
# CCCma/tasmax/CCCma_SRES_B2_TMAX_1-2412.grb
# CCCma/tasmax/CCCma_SRES_A2_TMAX_1-2412.grb
# CCCma/pr/CCCma_SRES_A2_PREC_1-2412.grb
# CCCma/pr/CCCma_SRES_B2_PREC_1-2412.grb
# CCCma/rsds/CCCma_SRES_B2_DSWF_1-2412.grb
# CCCma/rsds/CCCma_SRES_A2_DSWF_1-2412.grb
# CCCma/psl/CCCma_SRES_B2_MSLP_1-2412.grb
# CCCma/psl/CCCma_SRES_A2_MSLP_1-2412.grb
# CCCma/sn/CCCma_SRES_A2_SN_1-2412.grb
# NCAR/tas/NCARCSM_SRES_A2_TMP_1-1200.grb
# NCAR/tasmin/NCARCSM_SRES_A2_TMIN_1-1200.grb
# NCAR/tasmax/NCARCSM_SRES_A2_TMAX_1-1200.grb
# NCAR/pr/NCARCSM_SRES_A2_PREC_1-1200.grb
# NCAR/rsds/NCARCSM_SRES_A2_DSWF_1-1200.grb
# NCAR/psl/NCARCSM_SRES_A2_MSLP_1-1200.grb
# HCCPR/sfcWind/HADCM3_A2b_wind_1-1680.grb
# HCCPR/sfcWind/HADCM3_B2_wind_1-1800.grb
# HCCPR/sfcWind/HADCM3_A2c_wind_1-2880.grb
# HCCPR/sfcWind/HADCM3_A2_wind_1-1800.grb
# HCCPR/tas/HADCM3_A2_temp_1-1800.grb
# HCCPR/tas/HADCM3_B2_temp_1-1800.grb
# HCCPR/tasmin/HADCM3_A2_tmin_1-1800.grb
# HCCPR/tasmin/HADCM3_A2b_tmin_1-1680.grb
# HCCPR/tasmin/HADCM3_A2c_tmin_1-1680.grb
# HCCPR/tasmax/HADCM3_A2b_tmax_1-1680.grb
# HCCPR/tasmax/HADCM3_A2_tmax_1-1800.grb
# HCCPR/tasmax/HADCM3_A2c_tmax_1-1680.grb
# HCCPR/tasmax/HADCM3_B2_tmax_1-1800.grb
# HCCPR/pr/HADCM3_B2_prec_1-1800.grb
# HCCPR/pr/HADCM3_A2_prec_1-1800.grb
# HCCPR/rsds/HADCM3_A2_dswf_1-1800.grb
# HCCPR/rsds/HADCM3_A2b_dswf_1-1680.grb
# HCCPR/rsds/HADCM3_A2c_dswf_1-2880.grb
# HCCPR/rsds/HADCM3_B2_dswf_1-1800.grb
# HCCPR/psl/HADCM3_A2_mslp_1-1800.grb
# HCCPR/psl/HADCM3_B2_mslp_1-1800.grb
# HCCPR/sn/HADCM3_A2b_snat_1-1680.grb
# HCCPR/sn/HADCM3_A2_snat_1-1800.grb
# HCCPR/sn/HADCM3_A2c_snat_1-2880.grb
