# %%
import os
import xarray as xr
import pandas as pd
# %matplotlib inline

# %%
experiment_id_dict = {
    "1pctCO2": {"FAR":"1P", "SAR":"GG"},
    "historical": {"FAR":"1P", "SAR":"GS", "TAR":"SRES-A2"},
    "piControl": {"FAR":"CI", "SAR":"CI"}
}
source_id_attrs = {"FAR": "institution", "SAR": "institution", "TAR": "institution"}

# %%
activity_ids = ["FAR","SAR","TAR"]
variable_ids = ["tas","psl","pr", "rsds", "sn", "tasmax", "tasmin", "sfcWind"]
table_id = "Amon"

# %%
push_to_cloud = True

# %%
stop = 0
for activity_id in activity_ids:
    
    fs_dict = {
        "activity_id": [],
        "institution_id": [],
        "source_id": [],
        "experiment_id": [],
        "member_id": [], 
        "table_id": [], 
        "variable_id": [], 
        "grid_label": [], 
        "zstore": [],
        "dcpp_init_year": []
    }
    
    path_to_nc = f"../data/interim/{activity_id}/"
    for experiment_id in experiment_id_dict.keys():
        for variable_id in variable_ids:
            for ncfile in os.listdir(path_to_nc):
                if variable_id not in ncfile: continue # wrong variable
                if activity_id not in experiment_id_dict[experiment_id]: continue # experiment doesn't exist
                if experiment_id_dict[experiment_id][activity_id] not in ncfile: continue # wrong experiment

                ds = xr.open_dataset(path_to_nc+ncfile, decode_cf=False)

                # Write to zarr
                institution_id = ds.attrs[source_id_attrs[activity_id]]

                # If different source_id and member_id for a single institution (as in SAR)
                if activity_id == 'SAR':
                    source_id = institution_id+'-'+str(ncfile[2:4])
                    member_id = f"r{ncfile[7:8]}i1p1f1"
                else:
                    source_id = institution_id
                    member_id = "r1i1p1f1"
                
                zarr_name = f"{institution_id}/{source_id}/{experiment_id}/{member_id}/{table_id}/{variable_id}/gn/"
                path_to_zarr = f"../data/zarr/{activity_id}/"+zarr_name

                ds.to_zarr(path_to_zarr, mode='w', consolidated=True)

                fs_dict["activity_id"].append(activity_id)
                fs_dict["institution_id"].append(institution_id)
                fs_dict["source_id"].append(source_id)
                fs_dict["experiment_id"].append(experiment_id)
                fs_dict["member_id"].append(member_id)
                fs_dict["table_id"].append(table_id)
                fs_dict["variable_id"].append(variable_id)
                fs_dict["grid_label"].append("gn")
                fs_dict["zstore"].append(f"gs://ipcc-{activity_id.lower()}/{activity_id}/"+zarr_name)
                fs_dict["dcpp_init_year"].append("NaN")
                print(zarr_name)

    # Write csv catalog to Zarr data folder
    df = pd.DataFrame.from_dict(fs_dict)
    path_to_csv = f"../data/zarr/{activity_id}/pangeo-{activity_id.lower()}.csv"
    df.to_csv(path_to_csv, index=False)

    # Write catalog json to Zarr data folder
    os.system(f"cp ../catalogs/pangeo-{activity_id.lower()}.json ../data/zarr/{activity_id}/")   
    
    if push_to_cloud:
        print(f"\nPush {activity_id} data to Google Cloud storage:")
        transfer_command = f"../data/zarr/{activity_id} gs://ipcc-{activity_id.lower()}/"
        gsutil_command = f"gsutil -m cp -r {transfer_command}"
        print(gsutil_command+"\n\n")
        os.system(gsutil_command)
        os.system(f"gsutil -m cp ../data/zarr/{activity_id}/pangeo-{activity_id.lower()}.json  gs://ipcc-{activity_id.lower()}")
        os.system(f"gsutil -m cp ../data/zarr/{activity_id}/pangeo-{activity_id.lower()}.csv  gs://ipcc-{activity_id.lower()}")
# Out:
# UKTR/UKTR/1pctCO2/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL/1pctCO2/r1i1p1f1/Amon/tas/gn/
# GISS/GISS/1pctCO2/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL/1pctCO2/r1i1p1f1/Amon/pr/gn/
# GISS/GISS/1pctCO2/r1i1p1f1/Amon/pr/gn/
# UKTR/UKTR/1pctCO2/r1i1p1f1/Amon/pr/gn/
# GFDL/GFDL/1pctCO2/r1i1p1f1/Amon/sn/gn/
# GISS/GISS/1pctCO2/r1i1p1f1/Amon/sn/gn/
# UKTR/UKTR/historical/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/tas/gn/
# GISS/GISS/historical/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/pr/gn/
# GISS/GISS/historical/r1i1p1f1/Amon/pr/gn/
# UKTR/UKTR/historical/r1i1p1f1/Amon/pr/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/sn/gn/
# GISS/GISS/historical/r1i1p1f1/Amon/sn/gn/
#
# Push FAR data to Google Cloud storage:
# gsutil -m cp -r ../data/zarr/FAR gs://ipcc-far/
#
#
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r2i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-02/1pctCO2/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# NCAR/NCAR-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL-01/1pctCO2/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/1pctCO2/r2i1p1f1/Amon/psl/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# NCAR/NCAR-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# GFDL/GFDL-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/psl/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-02/1pctCO2/r1i1p1f1/Amon/psl/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-02/1pctCO2/r1i1p1f1/Amon/pr/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/pr/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/1pctCO2/r2i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/pr/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# NCAR/NCAR-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# GFDL/GFDL-01/1pctCO2/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-02/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# NCAR/NCAR-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# GFDL/GFDL-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/rsds/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/tasmax/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/tasmax/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/tasmax/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/tasmax/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/tasmin/gn/
# CSIRO/CSIRO-01/1pctCO2/r1i1p1f1/Amon/tasmin/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/tasmin/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/tasmin/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/tasmin/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/tasmin/gn/
# MPIfM/MPIfM-01/1pctCO2/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-02/1pctCO2/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-01/1pctCO2/r3i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-01/1pctCO2/r1i1p1f1/Amon/sfcWind/gn/
# CCCma/CCCma-01/1pctCO2/r1i1p1f1/Amon/sfcWind/gn/
# CCSR-NIES/CCSR-NIES-01/1pctCO2/r1i1p1f1/Amon/sfcWind/gn/
# NCAR/NCAR-01/1pctCO2/r1i1p1f1/Amon/sfcWind/gn/
# DKRZ/DKRZ-01/1pctCO2/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-01/1pctCO2/r4i1p1f1/Amon/sfcWind/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/historical/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/tas/gn/
# NCAR/NCAR-01/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL-01/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/historical/r2i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-02/historical/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-02/historical/r1i1p1f1/Amon/psl/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/psl/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/psl/gn/
# GFDL/GFDL-01/historical/r1i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/psl/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/psl/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/psl/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/psl/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/psl/gn/
# NCAR/NCAR-01/historical/r1i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/psl/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-02/historical/r1i1p1f1/Amon/pr/gn/
# DKRZ/DKRZ-01/historical/r2i1p1f1/Amon/pr/gn/
# GFDL/GFDL-01/historical/r1i1p1f1/Amon/pr/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/pr/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/pr/gn/
# NCAR/NCAR-01/historical/r1i1p1f1/Amon/pr/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/pr/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/pr/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/pr/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/pr/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/pr/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/rsds/gn/
# HCCPR/HCCPR-02/historical/r1i1p1f1/Amon/rsds/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/rsds/gn/
# NCAR/NCAR-01/historical/r1i1p1f1/Amon/rsds/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/rsds/gn/
# DKRZ/DKRZ-01/historical/r1i1p1f1/Amon/rsds/gn/
# GFDL/GFDL-01/historical/r1i1p1f1/Amon/rsds/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/rsds/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/rsds/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/rsds/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/rsds/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/rsds/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/tasmax/gn/
# DKRZ/DKRZ-01/historical/r1i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/tasmax/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/tasmax/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/tasmax/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/tasmax/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/tasmax/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/tasmax/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/tasmax/gn/
# CSIRO/CSIRO-01/historical/r1i1p1f1/Amon/tasmin/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/tasmin/gn/
# DKRZ/DKRZ-01/historical/r1i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/tasmin/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/tasmin/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/tasmin/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/tasmin/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/tasmin/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/historical/r4i1p1f1/Amon/sfcWind/gn/
# CCSR-NIES/CCSR-NIES-01/historical/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-01/historical/r3i1p1f1/Amon/sfcWind/gn/
# CCCma/CCCma-01/historical/r2i1p1f1/Amon/sfcWind/gn/
# CCCma/CCCma-01/historical/r3i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-01/historical/r2i1p1f1/Amon/sfcWind/gn/
# MPIfM/MPIfM-01/historical/r2i1p1f1/Amon/sfcWind/gn/
# NCAR/NCAR-01/historical/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-01/historical/r1i1p1f1/Amon/sfcWind/gn/
# MPIfM/MPIfM-01/historical/r1i1p1f1/Amon/sfcWind/gn/
# CCCma/CCCma-01/historical/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-02/historical/r1i1p1f1/Amon/sfcWind/gn/
# DKRZ/DKRZ-01/historical/r1i1p1f1/Amon/sfcWind/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/tas/gn/
# NCAR/NCAR-01/piControl/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL-01/piControl/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-02/piControl/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/tas/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/tas/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-02/piControl/r1i1p1f1/Amon/psl/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/psl/gn/
# NCAR/NCAR-01/piControl/r1i1p1f1/Amon/psl/gn/
# GFDL/GFDL-01/piControl/r1i1p1f1/Amon/psl/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/psl/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/psl/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/psl/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/psl/gn/
# NCAR/NCAR-01/piControl/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-02/piControl/r1i1p1f1/Amon/pr/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/pr/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/pr/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/pr/gn/
# GFDL/GFDL-01/piControl/r1i1p1f1/Amon/pr/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/pr/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/pr/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/pr/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/rsds/gn/
# GFDL/GFDL-01/piControl/r1i1p1f1/Amon/rsds/gn/
# HCCPR/HCCPR-02/piControl/r1i1p1f1/Amon/rsds/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/rsds/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/rsds/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/rsds/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/rsds/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/rsds/gn/
# NCAR/NCAR-01/piControl/r1i1p1f1/Amon/rsds/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/tasmax/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/tasmax/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/tasmax/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/tasmax/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/tasmax/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/tasmax/gn/
# CSIRO/CSIRO-01/piControl/r1i1p1f1/Amon/tasmin/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/tasmin/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/tasmin/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/tasmin/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/tasmin/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/tasmin/gn/
# CCSR-NIES/CCSR-NIES-01/piControl/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-02/piControl/r1i1p1f1/Amon/sfcWind/gn/
# HCCPR/HCCPR-01/piControl/r1i1p1f1/Amon/sfcWind/gn/
# MPIfM/MPIfM-01/piControl/r1i1p1f1/Amon/sfcWind/gn/
# DKRZ/DKRZ-01/piControl/r1i1p1f1/Amon/sfcWind/gn/
# CCCma/CCCma-01/piControl/r1i1p1f1/Amon/sfcWind/gn/
# NCAR/NCAR-01/piControl/r1i1p1f1/Amon/sfcWind/gn/
#
# Push SAR data to Google Cloud storage:
# gsutil -m cp -r ../data/zarr/SAR gs://ipcc-sar/
#
#
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/tas/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/tas/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/tas/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/tas/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/tas/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/tas/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/tas/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/tas/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/psl/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/psl/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/psl/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/psl/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/psl/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/psl/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/pr/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/pr/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/pr/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/pr/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/pr/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/pr/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/rsds/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/rsds/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/rsds/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/rsds/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/rsds/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/rsds/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/sn/gn/
# GFDL/GFDL/historical/r1i1p1f1/Amon/sn/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/sn/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/sn/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/tasmax/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/tasmax/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/tasmax/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/tasmax/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/tasmax/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/tasmin/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/tasmin/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/tasmin/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/tasmin/gn/
# NCAR/NCAR/historical/r1i1p1f1/Amon/tasmin/gn/
# MPIfM/MPIfM/historical/r1i1p1f1/Amon/sfcWind/gn/
# CSIRO/CSIRO/historical/r1i1p1f1/Amon/sfcWind/gn/
# CCCma/CCCma/historical/r1i1p1f1/Amon/sfcWind/gn/
# CCSR-NIES/CCSR-NIES/historical/r1i1p1f1/Amon/sfcWind/gn/
#
# Push TAR data to Google Cloud storage:
# gsutil -m cp -r ../data/zarr/TAR gs://ipcc-tar/
